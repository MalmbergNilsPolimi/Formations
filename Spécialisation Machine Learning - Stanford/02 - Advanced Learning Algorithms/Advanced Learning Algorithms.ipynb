# %% [markdown]
# # Advanced Learning Algorithms
#
# In this course we will talk about Neural Networks (inference/prediciton, training), advixe for building machine learning systems and decision trees

# %% [markdown]
# ## Neural Networks
#
# ### Introduction
#
# When NN was create, the main goal was to try to mimic the brain. Algorithms in this field were used in the 80's but fell out of flavor in the late 90's before resurging in 2005.
#
# <nop/> <div style="width: 500px;">![image.png](attachment:image.png)</div>
#
# Neural Network is based the biological neuron principles. One neuron receive several messages from other neurons, do a combination and then send an output to another neuron. So we have several inputs that gave us one output and this output goes into another neuron.
#
# Now let's take an example of demand prediction. We want ot known if a t-shirt will be the top seller or not. For that we take a training sample with answers for different prices. So we can first try to apply logistic regression on the price.
#
# <nop/> <div style="width: 500px;">![image-2.png](attachment:image-2.png)</div>
#
# But what happened know if consider other features as the shipping cost, marketing, material... Then we have 4 features. Instead of using one layer with one neuron giving use the probability of being a top seller, we can add another layer that will return some "activations" as the affordability, awareness, perceived quality and then use those three activations as inputs for a layer with one neuron that will give us the probability.
#
# <nop/> <div style="width: 500px;">![image-3.png](attachment:image-3.png)</div>
#
# So in a neural network, we can have several layers. Each layer can have one or several neurons and each neuron can receive one or more inputs. But in fact, if we have a lot of features, how to decide which feature goes to which neuron ? In practice, all neurons will received all features.
#
# <nop/> <div style="width: 500px;">![image-4.png](attachment:image-4.png)</div>
#
# A huge and difficult question is how many neurons and layers do we need? This is answer by neural network architecture.
# <nop/> <div style="width: 500px;">![image-5.png](attachment:image-5.png)</div>

# %% [markdown]
# ### Example of computer vision: facial recognition
#
# <nop/> <div style="width: 500px;">![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)</div>
